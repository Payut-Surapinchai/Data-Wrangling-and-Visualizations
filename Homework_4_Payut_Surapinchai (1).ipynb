# %% [markdown]
# # Homework 4: Due Wednesday, February 26 at 11:59 PM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
#
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 4 assignment in Canvas before <font color="dodgerblue">**11:59PM on Wednesday, February 26.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="Getting Started">Before You Get Started: Installing and Loading Packages</a>
#
# ---
#
# <font color="dodgerblue">**You will need to load three packages and then load a data frame each time you start a new Colab session to work on the problems in this assignment:**</font>
#
# 1. `ggplot2` to create plots.
#   - This package is already installed in Colab, but you still need to load the package with a `library()` command each time you start a new session.
# 2. `dplyr` to work with the `storms` data frame on questions [9](#Q9), [10](#Q10) and [11](#Q11).
# 3. `Stat2Data` to access the `Hawks` data frame that will be the data used in plots in questions [1](#Q1) thru [8](#Q8)..
#   - This package is NOT installed in Colab.
#   - You will need to first install the package.
#   - Then you will need to load the package with a `library()` command.
#   - You will need to repeat both the install and load of the `Stat2Data` package each time you start a new session.
#
# 4. After loading all three packages listed above, you will need to load the `Hawks` data frame from the `Stat2Data` package by running the command `data(Hawks, package = "Stat2Data")` which has been added in a separate code cell below.
#
#
# <font color="dodgerblue">**Make sure to you run these first code cells to load the `ggplot2`, `dplyr`, and `Stat2Data` packages as well as load the `Hawks` data frame each time you work on this assignment!**</font>

# %%
# write code to install and/or load required packages
library(ggplot2)
library(dplyr)
install.packages("Stat2Data")
library(Stat2Data)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# after installing and loading Stat2Data
# run this code cell to load Hawks data frame
##############################################################
# if you get an error, you did not load Stat2 Data correctly
##############################################################
data(Hawks, package = "Stat2Data")
str(Hawks)  # structure of Hawks data frame
# Out:
# 'data.frame':	908 obs. of  19 variables:
#  $ Month       : int  9 9 9 9 9 9 9 9 9 9 ...
#  $ Day         : int  19 22 23 23 27 28 28 29 29 30 ...
#  $ Year        : int  1992 1992 1992 1992 1992 1992 1992 1992 1992 1992 ...
#  $ CaptureTime : Factor w/ 308 levels " ","1:15","1:31",..: 181 25 138 42 62 71 181 88 261 192 ...
#  $ ReleaseTime : Factor w/ 60 levels ""," ","10:20",..: 1 2 2 2 2 2 2 2 2 2 ...
#  $ BandNumber  : Factor w/ 907 levels " ","1142-09240",..: 856 857 858 809 437 280 859 860 861 281 ...
#  $ Species     : Factor w/ 3 levels "CH","RT","SS": 2 2 2 1 3 2 2 2 2 2 ...
#  $ Age         : Factor w/ 2 levels "A","I": 2 2 2 2 2 2 2 1 1 2 ...
#  $ Sex         : Factor w/ 3 levels "","F","M": 1 1 1 2 2 1 1 1 1 1 ...
#  $ Wing        : num  385 376 381 265 205 412 370 375 412 405 ...
#  $ Weight      : int  920 930 990 470 170 1090 960 855 1210 1120 ...
#  $ Culmen      : num  25.7 NA 26.7 18.7 12.5 28.5 25.3 27.2 29.3 26 ...
# ...

# %% [markdown]
# ## <a name="about-hawks">Data Dictionary: Hawks Data Frame</a>
#
# ---
#
#  The `Hawks` data frame has 908 observations on 19 variables. More information about the data may be found by running the command `?Hawks`. Some of the variables we will consider are:
#
# - `Species`: `CH` = Cooper's, `RT` = Red-tailed, `SS` = Sharp-Shinned
# - `Age`: 	`A` = Adult or `I` = Immature
# - `Sex`:	`F` = Female or `M` = Male
# - `Wing`:	Length (in mm) of primary wing feather from tip to wrist it attaches to
# - `Weight`:	Body weight (in g)
# - `Culmen`:	Length (in mm) of the upper bill from the tip to where it bumps into the fleshy part of the bird
# - `Hallux`:	Length (in mm) of the killing talon
# - `Tail`:	Measurement (in mm) related to the length of the tail (invented at the MacBride Raptor Center)
# - `StandardTail`:	Standard measurement of tail length (in mm)
# - `Tarsus`:	Length of the basic foot bone (in mm)
# - `WingPitFat`:	Amount of fat in the wing pit
# - `KeelFat`:	Amount of fat on the breastbone (measured by feel)
#
# <br>
#
# **You MUST use `ggplot2` to construct all plots mentioned in this assignment, and you may NOT use Base R plotting functions (such as `plot`, `barplot`, `hist` or `boxplot`) to create any plots on this assignment.**

# %% [markdown]
# # <a name="Q1">Question 1</a>
#
# ---
#
# Construct a "basic" scatter plot of `Wing` (response variable on $y$-axis) versus `Weight` (predictor variable on $x$-axis) that maps `Species` to the `color` and `shape` aesthetics. For now, just add a geom layer for the scatter plot and do not worry about formatting non-data elements of the plot, but you **must map a `size` aesthetic locally inside the geom to slightly increase the size of the points** to a size of your liking.
#
# - *If you receive a warning message, include options in the geom to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
# - Assign the basic plot to an object that you name whatever you like.
# - Also print the plot to the screen so you and I can view it at this stage.
#
# <br>

# %%
# create a basic scatter plot and store it in the weight_wing_scatter object
weight_wing_scatter <- ggplot(Hawks, aes(x = Weight, y = Wing, color = Species, shape = Species)) +
                                geom_point(size = 3, na.rm = TRUE)  # there was errors due to missing values, so I used na.rm = TRUE to remove the missing values

weight_wing_scatter
# Out:
# plot without title

# %% [markdown]
# # <a name="Q2">Question 2</a>
#
# ---
#
# Using the "basic" scatter plot you created in [Question 1](#Q1), customize the plot by adding layers to perform the following edits:
#
# 1. Add a title to the plot and descriptive labels to the $x$ and $y$-axes.
# 2. Use a built-in `theme()` of your choice.
# 3. Move the legend to the top of the plot and increase the font size of all elements in the plot.
# 4. Change the color scale to a more colorblind-friendly scale using the function `scale_color_colorblind()`. (*Hint: You will need to load and install a package before you can access that function.*)
#   - This package has not been installed or loaded yet, you will need to do so as part of this question.
#
# You may choose to add all of these layers at once in one code cell or you may opt to add them one by one. Whatever you decide is fine with me! **In the end, be sure your final plot is printed to the screen and the output is viewable when you submit your work.**
#
# <br>

# %%
# I ran this code to install the ggthemes package, and import its library
install.packages("ggthemes")
library(ggthemes)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Use the basic scatter plot: "weight_wing_scatter", and add labels and themes to the plot
weight_wing_scatter +
  labs(
  main = "Body Weight and Wing Length Relationship",
  x = "Body Weight (in g)",
  y = "Wing Length (in mm)",
) + theme_light() +
  theme(legend.position = "top") +
  scale_color_colorblind()
# Out:
# plot without title

# %% [markdown]
# # <a name="Q3">Question 3</a>
#
# ---
#
# Interpret the results of the plot from [Question 2](#Q2). What can you learn about the weight and wing spans of the different species? Be sure to write your answer using complete sentences and refer to specific features and values in the graph if needed for clarity. The more specific and complete, the better!
#
# <br>

# %% [markdown]
# ## <a name="sol3">Solution to Question 3</a>
#
# ---
#
# From the plot in question 2, I can infer that all the species roughly have a positive association. However, the body and weight and wing length of Red-tailed hawks are significantly larger than both Sharp-shinned, and Cooper's. Not only that, it seems there are more spread or more data on Red-Tailed hawks when compared data of other hawks as well. (I'm not sure if the data are stacking on each other for the Cooper's and the Sharp-shinned, so I can't tell if what Red-tailed has is more data or more spread/noise)
#
#
# Although each species seems to have very different weight and wing length, I can see a little bit of blue points in the zone where there are black points. This means that some of the Sharp-shinned hawks do have the weight and wing length comparable to the Cooper's, but there only appears to be some selective few that are comparable, other than that the weight and wing length of the Sharp-shinned are significantly lower than the Cooper's. Which makes me believe that the blue points that are in the black points zone, are potential outliers, and shouldn't be paid much attention to. In addition, all the points that are not within their respective color group, seems to be potential outliers.
#
# (potential outliers because I have not statistically proved that they are outliers, therefore I could be wrong)
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q4">Question 4</a>
#
# ---
#
#
# Construct a "basic" scatter plot of `Culmen` (response variable on $y$-axis) versus `Weight` (predictor variable on $x$-axis) that globally maps `Species` to the `color` and `shape` aesthetics. Add simple linear regression lines to the scatter plot by adding a smoother layer.
#
# <br>
#
# - *If you receive a warning message, include options in the geom(s) to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
#   - You may need to include options in more than one geom to avoid the warning message.
#   - The message *`geom_smooth()` using formula = 'y ~ x'* is not a warning. That is fine to see when you run the code.
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Created a basic scatter plot having weight as x, culmen as y, and species for the color and shape
ggplot(Hawks, aes(x = Weight, y = Culmen, color = Species, shape = Species)

# Use the same geom_point and the parameters, and use geom_smooth(method = "lm") to create a linear regression model. I also used na.rm = TRUE to remove any missing values
) + geom_point(size = 3, na.rm = TRUE) + geom_smooth(method = "lm", na.rm = TRUE)
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # <a name="Q5">Question 5</a>
#
# ---
#
# Based on the plot in [Question 4](#Q4), answer the following questions. In all parts, write in complete sentence(s).
#
# Your writing should be intended for a non-technical, non-mathy general audience (not me). Do not write this for an audience that would understand what the term "slope" means for example.
#
# <br>
#
# a. For which species does the linear model have the greatest slope? Explain what is significant (if anything) about that property in terms of weight and culmen length. **Your answer should refer to the context (hawks, species, weight and culmen) and not mathy-terms such as slope, derivative, or intercept.** Use appropriate units when writing your answer.
#
# <br>
#
# b. For which species does the linear model seem to fit worst? Explain how you determined your answer.
#
#
# <br>

# %% [markdown]
# ## <a name="sol5">Solution to Question 5</a>
#
# ---
#
# <br>
#
#
#
# a. The Sharp-Shinned species have the greatest slope compared to other linear models in the scatter plot. This means that the blue points in the scatter plot are going towards the same direction (preferably go up) more than the other plots. You can see that the other line in the other plots are not really going to top right, and if the lines go top right, that indicates what we call a "positive association". Which basically means that both Weight (in g) and Culmen length (in mm) are both increasing at the same rate, which resulted in the line going top right, which is why I think that the Sharp-shinned species have the greatest slope.
#
#
#
#
#
# <br>
#
#
# b. I think the Cooper's species' linear model seem to fit the worst. Because first, the Cooper's points in the scatter plot seems to be spreading around a lot, and not only that, the Cooper's data group does not seem as large as the Red-Tailed data group. Which could result in the model not having enough data or noise to draw a good linear regression model. Not only that, from the plot, it seems that the line is not really aligning with the direction that the Cooper's points are going towards. Which is why I think that the Cooper's linear model fitted the worst.
#
#
#
#
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q6">Question 6</a>
#
# ---
#
#
# Construct a "basic" scatter plot of `Culmen` (response variable on $y$-axis) versus `Weight` (predictor variable on $x$-axis) with a smoother layer such that you pass aethestics to the geoms in a way that a single simple linear regression line is added to the scatter plot through all points (regardless of species), but the points are stilled colored and shaped differently depending on the `Species`.
#
# <br>
#
# - *If you receive a warning message, include options in the geom(s) to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
#   - You may need to include options in more than one geom to avoid the warning message.
#   - The message *`geom_smooth()` using formula = 'y ~ x'* is not a warning. That is fine to see when you run the code.
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a scatter plot, but use local aesthetics so it does not affect the linear model
ggplot(Hawks, aes(x = Weight, y = Culmen)
) + geom_point(size = 3, na.rm = TRUE, aes(color = Species, shape = Species)) +  # Implemented the local aesthetics in geom_point()
  geom_smooth(method = "lm", na.rm = TRUE)  # Create a linear model regression using geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # <a name="Q7">Question 7</a>
#
# ---
#
# Compare the plots in [Question 4](#Q4) and [Question 6](#Q6). Which linear model do you believe has less uncertainty in the predictions, the single linear model in [Question 6](#Q6) or the separate linear models created for each species in [Question 4](#Q4)? Explain how you determined your answer in one complete sentence.
#
#
# <br>

# %% [markdown]
# ## <a name="sol7">Solution to Question 7</a>
#
# ---
#
# The question 6's linear model has more uncertainty than question 4's linear model because each species has different data, and having models that are meant for each specific species are already a given that those models would be more accurate than a model that was developed for all the species.
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q8">Question 8</a>
#
# ---
#
# Construct a "basic" scatter plot of `Tail` (response variable on $y$-axis) versus `Wing` (predictor variable on $x$-axis) by adding aesthetics and/or faceting to include information about `Species` and `Age` variables in the following ways described in each part below.
#
# <br>
#
# - *If you receive a warning message, include options in the geom to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %% [markdown]
# ## <a name="Q8a">Question 8a</a>
#
# ---
#
# Do not map to any other aesthetics besides `x` and `y`, but add a layer for grid faceting with `Age` and `Species` such that each row corresponds to a different level of `Age` and each column corresponds to a different level of `Species`.

# %%
# Create a basic scatter plot
ggplot(Hawks, aes(x = Wing, y = Tail)
) + geom_point(na.rm = TRUE) + facet_grid(Age ~ Species)  # Use facet_grid to create grid facetting using Age as rows, and Species as columns
# Out:
# plot without title

# %% [markdown]
# ## <a name="Q8b">Question 8b</a>
#
# ---
#
# Map `Age` to the `color` and `shape` aesthetic in each scatter plot and add wrapped faceting with `Species`.
#
# <br>
#
# - *If you receive a warning message, include options in the geom to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a basic scatter plot using Age for color and shape
ggplot(Hawks, aes(x = Wing, y = Tail, color = Age, shape = Age)
) + geom_point(na.rm = TRUE) + facet_wrap(~Species)  # Use facet_wrap to create a wrap facetting using Species as the parameter
# Out:
# plot without title

# %% [markdown]
# ## <a name="Q8c">Question 8c</a>
#
# ---
#
# Map `Species` to the `color` and `shape` aesthetic in each scatter plot and add wrapped faceting with `Age`.
#
# <br>
#
# - *If you receive a warning message, include options in the geom to take care of the issue so you no longer receive a warning.*
#   - When you run the code, there should be no warning!
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a basic scatter plot using Species for color and shape
ggplot(Hawks, aes(x = Wing, y = Tail, color = Species, shape = Species)
) + geom_point(na.rm = TRUE) + facet_wrap(~Age)  # Use facet_wrap to create a wrap facetting using Age as the parameter
# Out:
# plot without title

# %% [markdown]
# # <a name="Q9">Question 9</a>
#
# ---
#
# The `dplyr` package contains a data set from the [NOAA Hurricane Best
# Track Data](https://www.nhc.noaa.gov/data/#hurdat) that contains data on
# the following attributes of tracked North Atlantic storms since 1975:
#
# -   Storm name: `name`
# -   Date and time: `year`, `month`, `day`, and `hour`
# -   Storm position: `lat` and `long`
# -   Storm classification: `status`
# -   Category of hurricane: `category` (non-hurricanes are `NA`)
# -   Wind speed (in knots): `wind`
# -   Pressure (in millibars): `pressure`
# -   Tropical storm force diameter (in nautical miles): `tropicalstorm_force_diameter`
# -   Hurricane force diameter (in nautical miles): `hurricane_force_diameter`
#
# Run the code cell below to load the `dplyr` package (if not already loaded from earlier) and print an initially summary of the structure of the `storms` data frame to the screen. Then answer the questions that follow.

# %%
# Import the dplyr library and print out the structure of storms
library(dplyr)
str(storms)
# Out:
# tibble [19,537 × 13] (S3: tbl_df/tbl/data.frame)
#  $ name                        : chr [1:19537] "Amy" "Amy" "Amy" "Amy" ...
#  $ year                        : num [1:19537] 1975 1975 1975 1975 1975 ...
#  $ month                       : num [1:19537] 6 6 6 6 6 6 6 6 6 6 ...
#  $ day                         : int [1:19537] 27 27 27 27 28 28 28 28 29 29 ...
#  $ hour                        : num [1:19537] 0 6 12 18 0 6 12 18 0 6 ...
#  $ lat                         : num [1:19537] 27.5 28.5 29.5 30.5 31.5 32.4 33.3 34 34.4 34 ...
#  $ long                        : num [1:19537] -79 -79 -79 -79 -78.8 -78.7 -78 -77 -75.8 -74.8 ...
#  $ status                      : Factor w/ 9 levels "disturbance",..: 7 7 7 7 7 7 7 7 8 8 ...
#  $ category                    : num [1:19537] NA NA NA NA NA NA NA NA NA NA ...
#  $ wind                        : int [1:19537] 25 25 25 25 25 25 25 30 35 40 ...
# ...

# %% [markdown]
# ## <a name="Q9a">Question 9a</a>
#
# ---
#
# Create a new data frame named `storms_status` that contains only the columns `month` and `status` from the `storms` data frame. Store both variables `month` and `status` as `factor` variables so they are both treated as categorical variables.
#
# - Run the command `str(storms_status)` before moving on to the next part to check your work.
#
# <br>

# %%
# Slice the storms data set to storms_status where storms_status only contains month and status columns
storms_status <- storms[,c("month", "status")]

# Convert the month and status columsn to factor type using factor ()
storms_status$month <- factor(storms_status$month)
storms_status$status <- factor(storms_status$status)
str(storms_status)
# Out:
# tibble [19,537 × 2] (S3: tbl_df/tbl/data.frame)
#  $ month : Factor w/ 10 levels "1","4","5","6",..: 4 4 4 4 4 4 4 4 4 4 ...
#  $ status: Factor w/ 9 levels "disturbance",..: 7 7 7 7 7 7 7 7 8 8 ...

# %% [markdown]
# ## <a name="Q9b">Question 9b</a>
#
# ---
#
# Create a "basic" bar chart with `month` mapped to the `x` aesthetic and `status` mapped to the `fill` aesthetic using the `"stack"` position. Position the legend on top of the plot.
#
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a bar plot with position = "stack"
ggplot(storms_status, aes(x = month, fill = status)
) + geom_bar(position = "stack") + theme(legend.position = "top")
# Out:
# plot without title

# %% [markdown]
# ## <a name="Q9c">Question 9c</a>
#
# ---
#
# Create a "basic" bar chart with `month` mapped to the `x` aesthetic and `status` mapped to the `fill` aesthetic using the `"fill"` position.  Position the legend on top of the plot.
#
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a bar plot with position = "fill"
ggplot(storms_status, aes(x = month, fill = status)
) + geom_bar(position = "fill") + theme(legend.position = "top")
# Out:
# plot without title

# %% [markdown]
# ## <a name="Q9d">Question 9d</a>
#
# ---
#
# Create a "basic" bar chart with `month` mapped to the `x` aesthetic and `status` mapped to the `fill` aesthetic using the `"dodge"` position. Position the legend on top of the plot.
#
# - You do not need to worry about formatting the layout of non-data elements such as labels, titles, themes, and fonts.
# - You do not need to assign the plot to an object.
#
# <br>

# %%
# Create a bar plot with position = "dodge"
ggplot(storms_status, aes(x = month, fill = status)
) + geom_bar(position = "dodge") + theme(legend.position = "top")
# Out:
# plot without title

# %% [markdown]
# ## <a name="Q9e">Question 9e</a>
#
# ---
#
# In which month did the most extratropical storms occur? Based on the graphs above (using no other code), approximately how many storms occurred in that month? Since you are basing your approximation on the graph alone, it is fine to give a rough approximation.
#
# <br>
#
# Which plot was most useful in helping you answer this question, the plot from Question [9b](#Q9b), [9c](#Q9c), or [9d](#Q9d)? Explain why in a complete sentence or two.
#
# <br>

# %% [markdown]
# ### <a name="sol9e">Solution to Question 9e</a>
#
# ---
#
# The 9th month had the most extratopical storms occurence, and there were aroundd 780 extratopical storms occurence in the 9th month.
#
# I used plot 9d to help me answer the question.
#
# Why:
# Because the fill plot is good for reading about proportions, and the stacked plot just looked too hard for me to see how many storms occurred and which month occurred the most. Therefore, I picked the dodge plot where you can easily observe which month had the most extra tropical storms, and also be able to roughly count how many storms occurred.
#
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="Q9f">Question 9f</a>
#
# ---
#
# Which month has the highest proportion of storms that are extratropical storms? Based on the graphs above (using no other code), approximately what proportion of storms that occurred in that month were extratropical storms?  Since you are basing your approximation on the graph alone, it is fine to give a rough approximation.
#
# <br>
#
# Which plot was most useful in helping you answer this question, the plot from Question [9b](#Q9b), [9c](#Q9c), or [9d](#Q9d)? Explain why in a complete sentence or two.
#
# <br>

# %% [markdown]
# ### <a name="sol9f">Solution to Question 9f</a>
#
# ---
# The 4th month has the highest proportion of extratropical storms. The approximation of the proportion of extratropical storms of the 4th month is 0.61.
#
# The plot from 9c was the most useful for helping me answer this question.
#
# Why:
# Because the plot from 9b and 9d are both plots that represent counts, therefore plot 9c was the only one suitable due to the y-axis representing proportions.
#
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q10">Question 10</a>
#
# ---
#
# Subset or slice the full `storms` data to create a data frame named `hur` that contains only the observations that have a `status` equal to `hurricane`.
#
# - Keep all variables in the new data frame `hur`.
# - Convert the variable `category` to a `factor` in the data frame `hur`.
# - Run the command `summary(hur)` before moving on to the next part to check your work.

# %%
# Slice the storms data set, where the status is equal to hurricane.
hur <- storms[storms$status == "hurricane",]

# Convert hur's category column to a factor using factor()
hur$category <- factor(hur$category)

summary(hur)
# Out:
#      name                year          month             day
#  Length:4803        Min.   :1975   Min.   : 1.000   Min.   : 1.00
#  Class :character   1st Qu.:1992   1st Qu.: 8.000   1st Qu.: 8.00
#  Mode  :character   Median :2001   Median : 9.000   Median :16.00
#                     Mean   :2001   Mean   : 8.952   Mean   :15.88
#                     3rd Qu.:2012   3rd Qu.: 9.000   3rd Qu.:24.00
#                     Max.   :2022   Max.   :12.000   Max.   :31.00
#
#       hour             lat             long
#  Min.   : 0.000   Min.   : 9.50   Min.   :-119.3
#  1st Qu.: 5.000   1st Qu.:19.70   1st Qu.: -76.2
#  Median :12.000   Median :26.40   Median : -63.2
#  Mean   : 9.156   Mean   :26.49   Mean   : -63.9
#  3rd Qu.:18.000   3rd Qu.:32.50   3rd Qu.: -51.8
#  Max.   :23.000   Max.   :50.80   Max.   : -14.1
#
#                     status     category      wind           pressure
#  hurricane             :4803   1:2548   Min.   : 65.00   Min.   : 882.0
# ...

# %% [markdown]
# # <a name="Q11">Question 11</a>
#
# ---
#
# Using the data frame `hur` you created in [Question 10](#Q10), create a bar plot to display the distribution of hurricanes by `category`. **Instead of using the default `stat` to display counts on the vertical axis, override the default `stat` to compute and display the maximum wind speed (`wind`) of hurricanes observed in each `category` on the vertical axis instead.**
#
#
# - The height of the bar over category 1 storms is the maximum wind speed of all category 1 hurricanes observed in the data.
# - The height of the bar over category 2 storms is the maximum wind speed of all category 2 hurricanes observed in the data.
# - And so on.
# - Make sure you adjust the label on the $y$-axis accordingly (it should not indicate "count").
# - Feel free to make any other "cosemtic" changes, but you are not required to do so.
#
#
# <br>

# %%
?geom_bar  # ran this code to see if I could learn more about the "stat=" parameter

# %%
# Create a scatter plot using hur, and use the category as x and wind as y
ggplot(hur, aes(x = category, y = wind)

# Use stat = "summary" to change the default stat, and since the stat = "summary" would use mean as the default. So, I pass in fun = max to make the default function turn into maximum instead of using mean.
) + geom_bar(stat = "summary", fun = max)
# Out:
# plot without title

# %% [markdown]
# # <a name="save2">Be Sure You Have Saved Your Work!</a>
#
# ---
#
# This notebook is a shared Colab notebook available for anyone to view. However, since everyone is sharing this notebook, you do not have permission to save changes to this shared Colab notebook. In order to save your work:
#
# 1. You will need to set up a free Google Drive account. If you already have a Google Drive account, you are ready to go!
# 2. Click the `Copy to Drive` button to the right of the `+ Code` and `+ Text` buttons on top of the notebook.
# 3. Select from the menu `File/Save a Copy in Drive`.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your Drive.
#   - Feel free to rename and store the notebook wherever you like.
