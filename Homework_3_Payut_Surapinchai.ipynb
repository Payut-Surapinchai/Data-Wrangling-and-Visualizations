# %% [markdown]
# # Homework 3: Due Wednesday, February 19 at 11:59 PM
#
# ---

# %% [markdown]
# ## <a name="HW1Inst">Instructions:</a>
# ---
#
# 1. <font color="tomato">Either click the COPY TO DRIVE button or use the menu File/Save/Save a Copy to save your own version of the notebook in your own folder in Google Drive.</font>
#
#   - If you do not have a Google account, you will need to create a Google account in order to create your own individual copy of this notebook.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your drive.
#   - Feel free to name and store the notebook wherever you like!
#
# 2. <font color="mediumseagreen">After you have copied the notebook into your Drive, you can begin editing and saving your work.</font>
#
# **Upload your completed assignment into Canvas as a Google Colab (or Jupyter) Notebook with file extension `.ipynb`.**
#
# Upload your file into the Homework 3 assignment in Canvas before <font color="dodgerblue">**11:59PM on Wednesday, February 19.**</font>
#
# **You must provide supporting work for your all of your answers.**
#
#   - <font color="dodgerblue">That work will include using R code cells.</font>
#     - **Feel free to insert as much R code as you like.**
#     - You must interpret or explain how the output of a code cell is being utilized to solve the problem.
#     - **Code with incomplete or missing explanations of why the output is useful may not receive full credit.**
#   - <font color="dodgerblue">Your work will also involve writing explanations and justifications in text cells.</font>
#     - **Be sure to type/write out the steps of your work/explanation so I can see how you arrived at your answer.**
#
#
# ## Important Academic Policies:
# ---
#
# - **Be your own work.** Though you may collaborate with others, everyone is responsible for writing up the work in their own way using their own methods. Plagiarism of any form is not tolerated.
# - **Be complete.** You must provide all work and/or explanations needed to find the solution. Answers with insufficient or incomplete supporting work may lose credit.
# - **Adhere to the Code of Academic Honesty.**
# - **Be clearly written (and legible if written).** Your solution to a problem must be clear, written in complete sentences. You may lose credit for work that is unclear or hard to follow.
#
# ## <font color="dodgerblue">Let me know if you need help, and **GOOD LUCK!!!**</font>
#
# ----

# %% [markdown]
# # <a name="Getting Started">Before You Get Started: Installing and Loading Packages</a>
#
# ---
#
# <font color="dodgerblue">**You will need to load two packages and then load a data frame each time you start a new Colab session to work on the problems in this assignment:**</font>
#
# 1. `ggplot2` to create plots.
#   - This package is already installed in Colab, but you still need to load the package with a `library()` command each time you start a new session.
# 2. `Stat2Data` to access the `Hawks` data frame that will be the data used in plots.
#   - This package is NOT installed in Colab.
#   - You will need to first install the package.
#   - Then you will need to load the package with a `library()` command.
#   - You will need to repeat both the install and load of the `Stat2Data` package each time you start a new session.
#
# 3. After loading both packages listed above, you will need to load the `Hawks` data frame from the `Stat2Data` package by running the command `data(Hawks, package = "Stat2Data")` which has been added in a separate code cell below.
#
#
# <font color="dodgerblue">**Make sure to load both the `ggplot2` and `Stat2Data` packages as well as load the `Hawks` data frame each time you work on this assignment!**</font>

# %%
# write code to install and/or load required packages
library(ggplot2)
install.packages("Stat2Data")
library(Stat2Data)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# after installing and loading Stat2Data
# run this code cell to load Hawks data frame
##############################################################
# if you get an error, you did not load Stat2 Data correctly
##############################################################
data(Hawks, package = "Stat2Data")
str(Hawks)  # structure of Hawks data frame
# Out:
# 'data.frame':	908 obs. of  19 variables:
#  $ Month       : int  9 9 9 9 9 9 9 9 9 9 ...
#  $ Day         : int  19 22 23 23 27 28 28 29 29 30 ...
#  $ Year        : int  1992 1992 1992 1992 1992 1992 1992 1992 1992 1992 ...
#  $ CaptureTime : Factor w/ 308 levels " ","1:15","1:31",..: 181 25 138 42 62 71 181 88 261 192 ...
#  $ ReleaseTime : Factor w/ 60 levels ""," ","10:20",..: 1 2 2 2 2 2 2 2 2 2 ...
#  $ BandNumber  : Factor w/ 907 levels " ","1142-09240",..: 856 857 858 809 437 280 859 860 861 281 ...
#  $ Species     : Factor w/ 3 levels "CH","RT","SS": 2 2 2 1 3 2 2 2 2 2 ...
#  $ Age         : Factor w/ 2 levels "A","I": 2 2 2 2 2 2 2 1 1 2 ...
#  $ Sex         : Factor w/ 3 levels "","F","M": 1 1 1 2 2 1 1 1 1 1 ...
#  $ Wing        : num  385 376 381 265 205 412 370 375 412 405 ...
#  $ Weight      : int  920 930 990 470 170 1090 960 855 1210 1120 ...
#  $ Culmen      : num  25.7 NA 26.7 18.7 12.5 28.5 25.3 27.2 29.3 26 ...
# ...

# %% [markdown]
# ## <a name="about-hawks">Data Dictionary: Hawks Data Frame</a>
#
# ---
#
#  The `Hawks` data frame has 908 observations on 19 variables. More information about the data may be found by running the command `?Hawks`. Some of the variables we will consider are:
#
# - `Species`: `CH` = Cooper's, `RT` = Red-tailed, `SS` = Sharp-Shinned
# - `Age`: 	`A` = Adult or `I` = Immature
# - `Sex`:	`F` = Female or `M` = Male
# - `Wing`:	Length (in mm) of primary wing feather from tip to wrist it attaches to
# - `Weight`:	Body weight (in g)
# - `Culmen`:	Length (in mm) of the upper bill from the tip to where it bumps into the fleshy part of the bird
# - `Hallux`:	Length (in mm) of the killing talon
# - `Tail`:	Measurement (in mm) related to the length of the tail (invented at the MacBride Raptor Center)
# - `StandardTail`:	Standard measurement of tail length (in mm)
# - `Tarsus`:	Length of the basic foot bone (in mm)
# - `WingPitFat`:	Amount of fat in the wing pit
# - `KeelFat`:	Amount of fat on the breastbone (measured by feel)
#
# <br>
#
# **You MUST use `ggplot2` to construct all plots mentioned in this assignment, and you may NOT use Base R plotting functions (such as `plot`, `barplot`, `hist` or `boxplot`) to create any plots on this assignment.**

# %% [markdown]
# # <a name="Q1">Question 1</a>
#
# ---
#
# Construct a bar plot for the `Species` variable.
#
# - Give a title to the plot.
# - Set all bars to the same color, but choose a color that is not the default color and something other than `steelblue`.
# - There should not be any legend on your plot.
# - Feel free to customize the layout in other ways if you like.
#
#
# <br>
#
#  <font color="dodgerblue">**Make sure you have already loaded the `ggplot2` and `StatsData` packages as well as loaded the `Hawks` data frame before you create any plots on this assignment. You will need to do so each time you start an R session to work on this assignment.**</font>

# %%
# Use ggplot to create a bar plot
ggplot(Hawks, aes(x = Species)
) +
  geom_bar(fill = "lightblue", color = "black") +  # geom_bar() instructs ggplot to make a bar plot
  labs(title = "Hawk Species",                     # use labs() for the title and the subtitle
       subtitle = "from the Stat2Data package") +
  theme(text = element_text(size=20)) +            # use theme() for adjusting the text size and for adjusting the y-axis ticks, increasing the ticks by 50 using seq()
  scale_y_continuous(breaks = seq(0,600,50))
# Out:
# plot without title

# %% [markdown]
# # <a name="Q2">Question 2</a>
#
# ---
#
# Summarize what you can learn about the `Species` distribution from the bar plot you created in [Question 1](#Q1). Be specific about the approximate number of hawks from each species and be sure to write in **complete sentence(s)**. Type your answer in the solution text cell provided below.
#
# <br>

# %% [markdown]
# ## <a name="Sol2">Solution to Question 2</a>
#
# ---
#
# From the Hawk Species bar chart in question 1, there are around 75 Cooper's hawks, 575 Red-tailed hawks, and 265 Sharp-shinned hawks.
#
# (I could get more accurate numbers of hawks, but the bar plot would look too messy due to the gridlines in my opinion.)
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q3">Question 3</a>
#
# ---
#
# Convert the frequnecy bar plot you constructed for `Species` in [Question 1](#Q1) (that has counts on the vertical axis) to a relative frequency bar plot (that has proportions on the vertical axis instead of counts). Use all of the same colors and and titles as you used in [Question 1](#Q1), but **now be sure to change the label on the vertical to indicate the proportion is being measured on the vertical axis**.
#
#
#
# <br>

# %%
# Similar to question 1, I used ggplot, geom_bar(), labs(), and theme the same way
ggplot(Hawks, aes(x = Species, y = after_stat(prop), group = 1)  # The only difference between question 1 and question 3 is y = after_start(prop), group = 1
) +                                                              # This basically makes the bar plot change from count to proportions
  geom_bar(fill = "lightblue", color = "black") +
  labs(title = "Hawk Species",
       subtitle = "from the Stat2Data package",
       y = "Proportion") +
  theme(text = element_text(size=20)) +
  scale_y_continuous(breaks = seq(0,1,0.1))
# Out:
# plot without title

# %% [markdown]
# # <a name="Q4">Question 4</a>
#
# ---
#
# Create a histogram of the `Wing` variable.
#
# - Give a title to the plot.
# - Label the $x$-axis so it is clear what attribute is being displayed along that axis, including the units of how the attribute is being measured.
# - Set all bars to the same color, but choose a color that is not the default color and something other than `steelblue`.
# - Set the border around each bar to `black`.
# - Set the number of bins or the width of each bin to a reasonable value (you decide what would be reasonable).
# - Feel free to customize the layout in other ways if you like.

# %%
summary(Hawks$Wing)  # I ran this code to find out the minimum and max so I can make accurate y-axis ticks
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    37.2   202.0   370.0   315.6   390.0   480.0       1

# %%
# I used ggplot(), geom_histogram(), labs(), and theme() to create this histogram
ggplot(Hawks, aes(x = Wing)
) +
  geom_histogram(
    na.rm=TRUE,
    binwidth = 20,  # Decided to use binwidth of 20 to see if the distribution is unimodal, bimodal, or multimodal, I tried other binwidth, but I felt like this is the best one
    fill = "azure", color = "black") +
      scale_y_continuous(breaks = seq(0, 500, by = 50)) +
      labs(title = "Hawk's Wing Length Histogram",
      x = "Hawk's Wing Length (in mm)") +
      theme(text = element_text(size=20))
# Out:
# plot without title

# %% [markdown]
# # <a name="Q5">Question 5</a>
#
# ---
#
# Summarize what you can learn about the `Wing` distribution from the plot you created in [Question 4](#Q4). Some interesting questions to consider:
#
# - Is the distribution unimodal, bimodal, multimodal?
#   - If values are cluster at certain values, which values?
# - Is the distribution symmetric or skewed?
# - Are there outliers, if so, in which direction?
# - Feel free to comment on any other interesting features you observe in the plot.
#
# Be sure to write in **complete sentence(s)**. Type your answer in the solution text cell provided below.
#
# <br>

# %% [markdown]
# ## <a name="Sol5">Solution to Question 5</a>
#
# ---
# From the Wing distribution, I can infer that the distribution is a bimodal distribution. The values seems to cluster in the 150-200 range, and 350-450 range.
#
#
# From the distribution in question 4, it may not be clear if the distribution is skewed or not, therefore I made another code below this question.
#
#
# From the distribution below, I made the distribution only have 5 bins, and it made it clearer that, the distribution is a left-skewed distribution. Apart from the distribution, my summary() also showed that the median is more than the mean, which also implies that the distribution is a left-skewed distribution.
#
#
# From the distribution in question 4, there seems to be outliers towards the left direction, because there is a small bar in the far left direction near 0, and then there's a gap which implies that the small bar in the far left is an outlier.
#
# The interesting thing about this plot or maybe any histogram plot in general is that I've found is when you change bins or binwidth, it changes how you can see the distribution especially if you are trying to infer if the graph is left-skewed, right-skewed, or symmetrical.
#
#
# <br>
# <br>

# %%
# Similar code to question 4, but I changed the binwidth to bins = 5 to be able to see the big picture of the histogram to be able to tell if it's skewed, or symmetric easier
ggplot(Hawks, aes(x = Wing)
) +
  geom_histogram(
    na.rm=TRUE,
    bins = 5,
    fill = "azure", color = "black") +
      scale_y_continuous(breaks = seq(0, 500, by = 50)) +
      labs(title = "Hawk's Wing Length Histogram",
      x = "Hawk's Wing Length (in mm)") +
      theme(text = element_text(size=20))
# Out:
# plot without title

# %% [markdown]
# # <a name="Q6">Question 6</a>
#
# ---
#
# Construct a density plot of the `Weight` variable. You do not need to customize the generic plot created unless you would like to. For example, you do not need to add any additional titles or labels to the plot.
#
# <br>

# %%
# Used ggplot() and geom_density() for a density plot
ggplot(Hawks, aes(x = Weight)
) +
  geom_density()
# Out:
# Warning message:
# “Removed 10 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# # <a name="Q7">Question 7</a>
#
# ---
#
# Map the variable `Sex` to an additional aesthetic (of your choice) to your density plot from [Question 6](#Q6). You do not need to customize the generic plot created unless you would like to. For example, you do not need to add any additional titles or labels to the plot.
#
# <br>

# %%
# Used ggplot() and geom_density() for a density plot
ggplot(Hawks, aes(x = Weight, color = Sex)  # Use color = Sex as the addition aesthetic
) +
  geom_density()
# Out:
# Warning message:
# “Removed 10 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# # <a name="Q8">Question 8</a>
#
# ---
#
# Map the variable `Species` to an additional aesthetic (of your choice) to your density plot from [Question 6](#Q6). You do not need to customize the generic plot created unless you would like to. For example, you do not need to add any additional titles or labels to the plot.
#
# *Note: You should no longer have `Sex` mapped to any aesthetic.*
#
# <br>

# %%
# Used ggplot() and geom_density() for a density plot
ggplot(Hawks, aes(x = Weight, fill = Species)  # Used fill = Species as the addition aesthetic
) +
  geom_density(alpha = 0.3)  # alpha = 0.3 has to do with the transparency in the plot
# Out:
# Warning message:
# “Removed 10 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# # <a name="Q9">Question 9</a>
#
# ---
#
# Map the variable `Age` to an additional aesthetic (of your choice) to your density plot from [Question 6](#Q6). You do not need to customize the generic plot created unless you would like to. For example, you do not need to add any additional titles or labels to the plot.
#
# *Note: You should no longer have `Sex` or `Species` mapped to any aesthetics.*
#
# <br>

# %%
# Used ggplot() and geom_density() for a density plot
ggplot(Hawks, aes(x = Weight, color = Age, linetype = Age)  # Used color = Age and linetype = Age as the additional aesthetics
) +
  geom_density()
# Out:
# Warning message:
# “Removed 10 rows containing non-finite outside the scale range
# (`stat_density()`).”
# plot without title

# %% [markdown]
# # <a name="Q10">Question 10</a>
#
# ---
#
# Based on the exploratory plots created in questions questions [Q7](#Q7), [Q8](#Q8), and [Q9](#Q9), answer the following questions using complete sentences in the text cell below.
#
# <br>
#
# a. Which of the categorical variable(s) (if any) have missing values? Explain how you determined your answer.
#
# <br>
#
#
# b. Which categorical variable has subpopulations (classes) with the biggest distinction in the distribution of `Weight` across each of the subpopulations of that variable? Explain how you determined your answer.
#
#
# <br>
# <br>

# %% [markdown]
# ## <a name="Sol10">Solution to Question 10</a>
#
# ---
#
# <br>
#
# a. I don't think any of the categorical variables have missing values, due to these reasons:
# 1. every plot I've made has the same errors of having 10 rows containing NAs, so I believe that the variable Weight is the one that has missing errors, and none of the categorical variables that I put as the aesthetics have missing values.
#
# 2. If there were missing values in the aesthetics, the density plot wouldn't be continuous and at one point there would be a gap, which doesn't appear here in any of the graphs.
#
#
#
# <br>
# <br>
#
#
# b. In my opinion, the categorical variable that has the biggest distinction in the distribution of Weight across each of the subpopulations would be "Species". Because you can see that the CH Species' maximum density is almost 0.01 while other subpopulations, their maximum density or their peak doesn't even reach 0.005. Therefore, I think this categorical variable has the biggest distinction in the distribution of Weight.
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q11">Question 11</a>
#
# ---
#
# Construct a density plot of the `Weight` variable mapping the categorical variable with the biggest distinction in the distribution of `Weight` across its subpopulations that you identfied in [Question 10b](#Q10) to the `fill` aesthetic. Now you should clean up the plot as follows:
#
# - Make sure the plot includes a legend. You can place it wherever you like.
# - There should not be any warning messages generated when creating your plot.
# - Adjust the shading of the fill so there is some transparency so no plot is completely hidden in the background.
# - Include a descriptive title for the plot.
# - Include a descriptive label for the $x$-axis (including units for the variable).
# - Feel free to bling up the plot however else you like!
#
# <br>

# %%
# Chose the Hawk Species as the distribution that had the most distinction between their subpopulations
# Used ggplot(), geom_density(), theme(), and labs() for this plot
ggplot(Hawks, aes(x = Weight, color = Species, fill = Species)
) +
  geom_density(na.rm = TRUE,
               alpha = 0.2, ) +
  theme(legend.position = "right", text = element_text(size=15)) +
  labs(title = "The Density Plot of Hawk Species",
       x = "Weight (in g)")
# Out:
# plot without title

# %%
?theme  # I ran this to check how theme works for ggplot2

# %% [markdown]
# # <a name="Q12">Question 12</a>
#
# ---
#
# Slice or subset the `Hawks` data frame to create a data frame named `fm` that contains the observations in `Hawks` that have `Sex` equal to `M` (male) or equal to `F` (female). Then print a summary of `fm` to the screen to verify the code worked properly. Keep all of the original variables from `Hawks` in `fm`.
#
# <br>

# %%
summary(Hawks)  # I wanted to see how the Sex variable in the Hawks dataset look like, before I start doing the slicing so I can see the difference
# Out:
#      Month             Day             Year       CaptureTime   ReleaseTime
#  Min.   : 8.000   Min.   : 1.00   Min.   :1992   11:35  : 14          :842
#  1st Qu.: 9.000   1st Qu.: 9.00   1st Qu.:1995   13:30  : 14   11:00  :  2
#  Median :10.000   Median :16.00   Median :1999   11:45  : 13   11:35  :  2
#  Mean   : 9.843   Mean   :15.74   Mean   :1998   12:10  : 13   12:05  :  2
#  3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:2001   14:00  : 13   12:50  :  2
#  Max.   :11.000   Max.   :31.00   Max.   :2003   13:05  : 12   13:32  :  2
#                                                  (Other):829   (Other): 56
#       BandNumber  Species  Age     Sex          Wing           Weight
#            :  2   CH: 70   A:224    :576   Min.   : 37.2   Min.   :  56.0
#  1142-09240:  1   RT:577   I:684   F:174   1st Qu.:202.0   1st Qu.: 185.0
#  1142-09241:  1   SS:261           M:158   Median :370.0   Median : 970.0
#  1142-09242:  1                            Mean   :315.6   Mean   : 772.1
# ...

# %%
# Use the method of slicing the Hawks dataset and storing it in the variable "fm"
fm <- Hawks[Hawks$Sex == "M" | Hawks$Sex == "F",]
summary(fm)  # print out the summary to check if it worked
# Out:
#      Month             Day             Year       CaptureTime   ReleaseTime
#  Min.   : 9.000   Min.   : 1.00   Min.   :1992   10:10  :  5          :301
#  1st Qu.: 9.000   1st Qu.:10.00   1st Qu.:1997   10:15  :  5   12:50  :  2
#  Median :10.000   Median :16.50   Median :2000   10:30  :  5   14:45  :  2
#  Mean   : 9.684   Mean   :16.07   Mean   :1999   11:35  :  5   10:20  :  1
#  3rd Qu.:10.000   3rd Qu.:23.00   3rd Qu.:2002   12:10  :  5   10:32  :  1
#  Max.   :11.000   Max.   :31.00   Max.   :2003   12:20  :  5   10:42  :  1
#                                                  (Other):302   (Other): 24
#       BandNumber  Species  Age     Sex          Wing           Weight
#  1142-09240:  1   CH: 68   A:101    :  0   Min.   :143.0   Min.   :  56.0
#  1142-09241:  1   RT:  4   I:231   F:174   1st Qu.:169.0   1st Qu.: 102.5
#  1142-09242:  1   SS:260           M:158   Median :195.0   Median : 169.0
#  1142-18229:  1                            Mean   :199.8   Mean   : 216.9
# ...

# %% [markdown]
# # <a name="Q13">Question 13</a>
#
# ---
#
# Use the `fm` data frame you constructed in [Question 12](#Q12) to construct a boxplot to display the distribution of `Tail` lengths (in mm) separately for female and male hawks in the data set. You should clean up the plot as follows:
#
# - Each box should be colored differently.
# - Include a descriptive title for the plot.
# - Include a descriptive label the axis displaying `Tail` so it is clear what is being displayed and what the units are.
# - Make sure there is a label on the axis displaying `Sex` or add one if not.
# - Make sure there is a legend or labels on the appropriate axis indicating which box corresponds to which sex.
# - Feel free to bling up the plot however else you like!
#
# <br>

# %%
# Used ggplot(), geom_boxplot(), labs(), and theme() to create a boxplot
ggplot(fm, aes(x = Tail, color = Sex)
) +
  geom_boxplot() +
  labs(title = "The Boxplot of Hawk's Sex Tail Length",
       x = "Tail Length (in mm)",
       y = "Sex") +
  theme(axis.ticks.y = element_blank(),  # axis.ticks.y and axis.text.y has to do with the ticks and text on the y-axis, in my opinion we didn't need it so I removed them using element_blank()
        axis.text.y = element_blank(),
        text = element_text(size=15))
# Out:
# plot without title

# %% [markdown]
# # <a name="Q14">Question 14</a>
#
# ---
#
# Comment on the difference in distribution of tail lengths between male and female hawks using the plot above. Use complete sentences.
#
#
# <br>

# %% [markdown]
# ## <a name="Sol14">Solution to Question 14</a>
#
# ---
#
# From the boxplot, it appears that female hawks' tail lengths are generally longer than male's because the mean of the female hawks' tail length is much higher than male's hawk as well as how the female hawks' tail outliers are longer in length when compared to male hawks' tail length. In addition, the female's boxplot seems to be shifted to the right more than the male which suggests that female hawks' tail length are longer than male hawks' tail lengths.
#
#
# <br>
# <br>

# %% [markdown]
# # <a name="Q15">Question 15</a>
#
# ---
#
# Slice or subset the `Hawks` data frame to create a data frame named `adult` that contains the observations in `Hawks` that have `Age` equal to `A` (adult).
#
# <br>
#
# Then use the `adult` data frame to construct a violin plot to display the distribution of `Culmen` lengths (in mm) separately for each `Species` of hawk in the `adult` data frame. After looking at the plot, it should be very clear which species has the longest, second longest, and shortest culmen length!
#
# <br>
#
# Be sure you do not get any warnings for missing values when creating the plot. If you do, modify the code so you no longer receive the warning the message. Outside of that, you do not need to clean up the plot any further.
#
# <br>
#
# *Note: The culmen length (in mm) is the distance on the upper bill from the tip to where it bumps into the fleshy part of the bird.*
#
# <br>

# %%
# Used the method of slicing to store the Hawks dataset when Hawk's Age is equal to A, and store it in the "adult" variable
adult <- Hawks[Hawks$Age == "A",]

# Used ggplot(), geom_violin, labs(), and theme to create this violinplot
ggplot(adult, aes(x = Culmen, y = Species, color = Species, fill = Species)
) +
  geom_violin(na.rm = TRUE, alpha = 0.3) +
  labs(title = "Hawk's Species and their Culmen Length",
  x = "Culmen (in mm)") +
  theme(text = element_text(size=15))
# Out:
# plot without title

# %% [markdown]
# # <a name="save2">Be Sure You Have Saved Your Work!</a>
#
# ---
#
# This notebook is a shared Colab notebook available for anyone to view. However, since everyone is sharing this notebook, you do not have permission to save changes to this shared Colab notebook. In order to save your work:
#
# 1. You will need to set up a free Google Drive account. If you already have a Google Drive account, you are ready to go!
# 2. Click the `Copy to Drive` button to the right of the `+ Code` and `+ Text` buttons on top of the notebook.
# 3. Select from the menu `File/Save a Copy in Drive`.
#   - By default, the notebook will be saved in a folder named **Colab Notebooks** in your Drive.
#   - Feel free to rename and store the notebook wherever you like.
